# %% [markdown]
# # 01. Importing libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
#Define path
path = r'C:\Users\Josh Abrams\Desktop\09-2022 Instacart Basket Analysis'

# %%
df_ords_prior = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'order_products_prior.csv'), index_col = False)

# %%
df_ords_prior = pd.read_csv(r'C:\Users\Josh Abrams\Desktop\09-2022 Instacart Basket Analysis\Data\Original Data\order_products_prior.csv', index_col = False)

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords= pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'df_ords_cleaned.csv'), index_col = False)

# %%
df_ords = pd.read_csv(r'C:\Users\Josh Abrams\Desktop\09-2022 Instacart Basket Analysis\Data\Prepared Data\df_ords_cleaned.csv', index_col = False)

# %%
df_ords.drop_duplicates( inplace=True)

# %%
df_ords
# Out:
#          Unnamed: 0  order_id  customer_id eval_set  order_number  \
# 0                 0   2539329            1    prior             1
# 1                 1   2398795            1    prior             2
# 2                 2    473747            1    prior             3
# 3                 3   2254736            1    prior             4
# 4                 4    431534            1    prior             5
# ...             ...       ...          ...      ...           ...
# 3421078     3421078   2266710       206209    prior            10
# 3421079     3421079   1854736       206209    prior            11
# 3421080     3421080    626363       206209    prior            12
# 3421081     3421081   2977660       206209    prior            13
# 3421082     3421082    272231       206209    train            14
#
#          orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                         2                  8                     NaN
# ...

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3421083, 8)

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large
# Out:
#           Unnamed: 0  order_id  customer_id eval_set  order_number  \
# 0                  0   2539329            1    prior             1
# 1                  0   2539329            1    prior             1
# 2                  0   2539329            1    prior             1
# 3                  0   2539329            1    prior             1
# 4                  0   2539329            1    prior             1
# ...              ...       ...          ...      ...           ...
# 32434484     3421081   2977660       206209    prior            13
# 32434485     3421081   2977660       206209    prior            13
# 32434486     3421081   2977660       206209    prior            13
# 32434487     3421081   2977660       206209    prior            13
# 32434488     3421081   2977660       206209    prior            13
#
#           orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                          2                  8                     NaN
# ...

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0  order_id  customer_id eval_set  order_number  \
# 0           0   2539329            1    prior             1
# 1           0   2539329            1    prior             1
# 2           0   2539329            1    prior             1
# 3           0   2539329            1    prior             1
# 4           0   2539329            1    prior             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Export data to csv

df_merged_large.to_csv(os.path.join(path, 'Data','Prepared Data', 'orders_products_combined.csv'))

# Export data to pkl

df_merged_large.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_combined.pkl'))
